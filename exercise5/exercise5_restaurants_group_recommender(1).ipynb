# %% [markdown]
# # Social Computing - Summer 2018
# # Exercise 5 - Group Recommender System
#
# ### Background
# In exercise 3 we built a simple collaborative filtering recommender system for
# movies using the MovieLens dataset. In this exercise we will reuse and extend this system  to build a group recommender system for restaurants. A group recommender provides recommendations for a group of users instead of a single user. A Group recommendation is an aggregation of single user recommendations generated to each group member. There are two possibilities to do this aggregation:
# * The first is to generate recommendations (predicted ratings) for individual members of the group (like a single user recommender), then aggregate those individual predicted ratings into predicted ratings (recommendations) for the group.
# * The second is to aggregate individual user ratings (actual ratings) to build a group model, and then create predicted ratings for the model, i.e. treating the group model as a single user and create predicted ratings for that user (using the single user recommender system)
#
# In both cases, the aggreation is done according to a social choice strategy (e.g. Maximum satisficaction, minimum misery, etc...)
# For more information about group recommenders and aggregation strategy, please refer to the paper: Group Recommender Systems: New Perspectives in the Social Web by Cantador and Castells (You will find it the reading material for this exercise)
#
# In this exercise, we will use to the first design option: The system should generate predicted ratings for each member of the group and those ratings will be aggregated into a group rating based on the "Least Misery" strategy.
#
# The group recommender system we will be build in this exercise is a social-context-aware recommender system and the input will be a subset of the anonymized restaurant rating dataset that the students submitted in the experiment part of this class. The "restaurant domain expertise" will be used as the social context parameter that will influence the output of the group recommender.
#
# The dataset is available in 2 comma-separated files: ratings.csv, and domain-expertise.csv
# * Ratings.csv contains individual participant restaurant ratings according to the rating attributes: price, clumsiness, service, hippieness, location, social overlap. The first two columns in the csv are for participant ID and restaurant ID respectively. The rating values for each of the attributes are between 0 and 100.
# * domain-expertise.csv: Each record contains the restaurant experitise rating of a participant as estimated by another participant. The file has 3 columns from_participant_id: The ID of the participant who did the rating, to_participant_id: The ID of the participant being rated, and domain_expertise: the rating value between 0 and 100
#
#
# ### The Exercise
# Write a simple group recommender system in python. The entry point to the program should be a method that takes the following arguments:
# * group: a list of integers which represents the participant IDs of some participants forming a group
# * ratings_path: path to the files ratings.csv
# * domain_expertise_path: path to the file domain-expertise.csv.
#
# Pre-processing:
#
# The restaurant ratings in the dataset are multi-valued (because there are several rating parameters for a single restaurant). Your program should calculate a single that represents the overall rating for each restaurant by each participant. The single value rating should be between 0 and 1 (divide the different rating values by 100 and calculate the average).
# The same applies for domain expertise ratings (divide the rating values by 100)
#
# Single-user recommendations:
#
# The program should generate individual recommendations for each participant in the group. A delegation-based-method that takes into consideration the domain-expertise of other participants in the group will be used. The idea is that a member's preference will be influenced by the opinion of another member in the group depending on how much she thinks this other person has expertise in the domain in question: if the person thinks that the other group member is an expert in restaurants, then she will be influenced by that members's opinion while choosing a restaurant for a group dinner for example. The delegation-based-method is formulated as follows:
# $$pred'(u,i) = \frac{1}{\mid{\sum_{v \in G} d_{u,v}\mid}}\sum_{v \in G \wedge v \neq u}d_{u,v}*pred(v,i)$$
# * $pred'(u,i)$ is the social-context-aware predicted rating of participant u to the restaurant i
# * $v$ is another member in the group $G$
# * $d_{u,v}$ is the domain expertise rating from participant u to participant v
# * $pred(v,i)$ is the predicted rating of participant v to the restaurant it
#
# According to the formula, you will notice that there are two different predicted ratings: pred and pred'.
# * pred: represents a normal collaborative filtering predicted rating for a certain user towards a certain item. We call this the base rating
# * while pred': is the social-context-aware predicted rating which is function in the base  rating of the other group members and with those members' domain expertise as preceived by the current user.
#
# This means your program should calculate two different ratings for each group member
# The program should start by calculating the base predicted rating for all members in the group for all restaurants (re-use your code from exercise 3), then for each group member, the program should calculate the social-context-aware predicted rating for all restaurants
#
# The final step in the program should be the calculation of the group recommendation, or the appliation of the aggregation strategy. The strategy we are going to use in this exercise is: "Least misery"
#
# The output should be a list of Python tuples (sorted by the groups restaurants' predicted ratings: highest first). Each tuple has the following two attributes: restaurant's ID, and social-context-aware predicted rating. You are free to design your recommendation engine the way as you want (the provided code below is just a suggested design). Clean, readable, and documented code is expected, and those aspects will be part of the overall grade of the exercise
#
# Note: You can test your recommender with the following groups (identified by the participant IDs): [63,117,116], [160,161,162], [178,134,91], [67,198,197]

# %%
import math

# TODO: Least misery strategy for group recommendations aggregation


def least_misery(social_preds, restaurants, group):
    group_ratings = []
    # TODO: implement strategy
    for restaurant in restaurants:
        grp_rating = 1
        for member in social_preds:            
            if grp_rating > social_preds[member][restaurant]:
                grp_rating = social_preds[member][restaurant] 
        group_ratings.append((restaurant, grp_rating))
    group_ratings.sort(key = lambda tup: tup[1], reverse = True) 
    return group_ratings


def calculate_social_context_aware_predictions(group, restaurants, base_predicted_ratings, dom_expertise):
    #TODO: Apply the formula for the participant for each restaurant
    social_preds = {}
    for member in group:
        for restaurant in restaurants:
            if member not in social_preds:
                social_preds[member] = {}
            dom_sum = 0
            dom_base_prod = []
            for other_members in group:
                if member != other_members:
                    dom_sum += dom_expertise[str(member)][str(other_members)]
                    dom_base_prod.append(dom_expertise[str(member)][str(other_members)]*base_predicted_ratings[str(other_members)][str(restaurant)])

            social_preds[member][restaurant] = (1/dom_sum)*(sum(dom_base_prod))    
            
    return social_preds # {participant_id: {restaurant_id: social_rating}}

# Using Euclidean distance to calculate similarity score
def calculate_similarity_score(ratings, user_id1, user_id2):
    common_movies = []
    # TODO Find common movies rated by both users
    user1_movies = ratings[user_id1]    
    user2_movies = ratings[user_id2]
    
    for movie in user2_movies:
        if movie in user1_movies:
            common_movies.append(movie)            
            
    if len(common_movies) == 0: # no common ratings between two users. Similarity is 0
        return 0

    # TODO Calculate Euclidean distance between two users based on their common ratings
    sum_of_squares_of_differences = 0
    for movie_id in common_movies:    
        sum_of_squares_of_differences += (user1_movies[movie_id] - user2_movies[movie_id])**2
        
        # TODO Accumulate the sum of squares of differences in ratings between the two users for the same movie
    return 1 / (1 + sum_of_squares_of_differences)   

    

def cf_recommend(target_user_id, restaurants, ratings, avg_ratings):
    weighted_ratings = {} # {movie_id: weighted_rating}
    similarity_scores = {} # {movie_id: similarity_score}
    recommended_movie_list = {} # Each element is a tuple (estimated_rating, movie_id)
    for user_id in ratings:
        if user_id != target_user_id:
            similarity_score = calculate_similarity_score(ratings, target_user_id, user_id)
            if similarity_score > 0:
                for movie_id in ratings[user_id]:
                    # Movie was not recommended by the target user before
                    if movie_id not in ratings[target_user_id]:
                        try:
                            if movie_id in weighted_ratings:
                                weighted_ratings[movie_id] += ratings[user_id][movie_id]*similarity_score
                                similarity_scores[movie_id] += similarity_score
                            else:
                                weighted_ratings[movie_id] = ratings[user_id][movie_id]*similarity_score
                                similarity_scores[movie_id] = similarity_score
                        except KeyError:
                            print("key error found! " + str(user_id) + " " + str(movie_id))
  
    for key in weighted_ratings: # TODO for each movie
        # TODO Weighted_rating/sigma (similarity scores of users who rated that movie)
        estimated_rating = weighted_ratings[key]/similarity_scores[key]
        recommended_movie_list[key] = estimated_rating
       
    for restaurant in restaurants:
        if restaurant not in weighted_ratings:
            recommended_movie_list[restaurant] = avg_ratings[restaurant]
        
        
    return recommended_movie_list # List of recommended movies for user_id from highest to lowest estimated rating

def calculate_base_predictions(item, restaurants, ratings, avg_ratings):
    return cf_recommend(item, restaurants, ratings, avg_ratings)
    

def get_restaurants(ratings_path): 
    #TODO: using the ratings return a list of unique restaurant IDs
    restaurants_list = list()
    f = open(ratings_path, 'r')
    lines = f.readlines()[1:]
    for line in lines:    
        rating_data = line.strip().split(',')
        if rating_data[1] not in restaurants_list:
            restaurants_list.append(rating_data[1])
    
    return restaurants_list



def get_participants(ratings_path): 
    #TODO: using the ratings return a list of unique restaurant IDs
    
    participants = []
    f = open(ratings_path, 'r')
    lines = f.readlines()[1:]
    
    for line in lines:
        ratings_data = line.split(',')
        participants.append(ratings_data[0])        
    participants = set(participants)
    return participants


def create_ratings_dictionary(path):
    ratings_dictionary = {}
    avg_ratings = {}
    file  = open(path, 'r')
    flag = 0
    count = {}
    
    for line in file:
        if flag == 1:
            ratings_info = line.split(',')
            if ratings_info[0] not in ratings_dictionary:
                ratings_dictionary[ratings_info[0]] = {}
            ratings_dictionary[ratings_info[0]][ratings_info[1]] = ((float(ratings_info[2])/100)+(float(ratings_info[3])/100)+(int(ratings_info[4])/100)+(float(ratings_info[5])/100)+(float(ratings_info[6])/100)+(int(ratings_info[7])/100))/6
            if ratings_info[1] in avg_ratings:
                avg_ratings[ratings_info[1]] += ((float(ratings_info[2])/100)+(float(ratings_info[3])/100)+(float(ratings_info[4])/100)+(float(ratings_info[5])/100)+   (float(ratings_info[6])/100)+(float(ratings_info[7])/100))/6
                count[ratings_info[1]] += 1
            else:
                avg_ratings[ratings_info[1]] = ((float(ratings_info[2])/100)+(float(ratings_info[3])/100)+(float(ratings_info[4])/100)+(float(ratings_info[5])/100)+   (int(ratings_info[6])/100)+(float(ratings_info[7])/100))/6
                count[ratings_info[1]] = 1
        flag = 1
        
        
    for key in avg_ratings:
        avg_ratings[key] = avg_ratings[key]/count[key]
    
    
    return ratings_dictionary, avg_ratings

def create_domain_dictionary(domain_expertise_path):
    domain_dict = {}
    f = open(domain_expertise_path, 'r')
    lines = f.readlines()[1:]
    for line in lines:
        domain_data = line.split(',')
        if domain_data[0] not in domain_dict:
            domain_dict[domain_data[0]] = {}
        domain_dict[domain_data[0]][domain_data[1]] = float(domain_data[2])/100        
    
    return domain_dict

# Group recommender (Main program)
def group_recommender(group, ratings_path, domain_expertise_path):
    # Pre-processing:
    #-----------------
    ratings, avg_ratings = create_ratings_dictionary(ratings_path)
    
    dom_expertise = create_domain_dictionary(domain_expertise_path)

    restaurants = list(get_restaurants(ratings_path))
    participants = list(get_participants(ratings_path))
    
    # Calculate single user recommendations (predicted ratings):
    #-------------------------------------------------------------
    # For each participant in the group, calculate the base ratings for each restaurant
    # For each participant in the group, calculate the social-context-aware predicted ratings (given the base predicted ratings)
    base_preds = {}
    for item in participants:
        base_preds[item] = calculate_base_predictions(item, restaurants, ratings, avg_ratings)
   
    # Calculate group recommendations (group predicted ratings) - based on the "Least Misery" strategy:
    #--------------------------------------------------------------------------------------------------
    # Given the social-context-aware predicted ratings for each group member, aggregate those ratings 
    # into group recommendations for each restaurant based on the "Least Misery" strategy (sorted by predicted ratings: highest first)
    social_preds = {}
    social_preds = calculate_social_context_aware_predictions(group, restaurants, base_preds, dom_expertise)
    group_ratings = least_misery(social_preds, restaurants, group)
    
    for i in range(len(group_ratings)):
        print(group_ratings[i])
        
# Test (Call your main program to test it with the sample groups from the exercise description above)
group_recommender([160,161,162], "ratings.csv", "domain_expertise.csv")
# Out:
# ('ChIJi8mM2MR1nkcREr7RKfG-r-A', 2.675)
# ('ChIJ0SA6ol7fnUcRY94JlDkvHIM', 2.62)
# ('ChIJn1i9catjnkcRUfGk3lw0nfs', 2.5949999999999993)
# ('ChIJ9UAZIc2SHyMRvjDjbD8RAZ8', 2.5799999999999996)
# ('ChIJl1jXp-x1nkcRWOz1L2XZjOg', 2.5749999999999997)
# ('ChIJk_E9pRJ1nkcR_gj14oF1w4U', 2.5599999999999996)
# ('ChIJPVuIx17MHkcRLTw4MxAEGqg', 2.54)
# ('ChIJs9m2L4h1nkcRH33znwtpr64', 2.5199999999999996)
# ('ChIJV8ScsvR1nkcRNjb_cjiH1_M', 2.4949999999999997)
# ('ChIJvUdRyzDEyIARh86Fi1C2hqI', 2.48)
# ('ChIJvU0_gel1nkcRT4LaXa2PuNI', 2.465)
# ('ChIJF4NRh96TyzsRuQItK64EJW4', 2.45)
# ('ChIJ56fJIvd1nkcRvJ7vYPfBkME', 2.4199999999999995)
# ('ChIJS0pws8-WyzsRXFPfkYpmjNY', 2.415)
# ('ChIJ8_kwAYTYnUcRf7LU6AZtsrQ', 2.4049999999999994)
# ('ChIJ_Q8c8ESRyzsRLZngwt4GTh8', 2.395)
# ('ChIJbyS9yOR1nkcRUCwH80RQmX8', 2.383)
# ('ChIJc1iaGGDfnUcRUvk6-kRjpQ0', 2.3749999999999996)
# ('ChIJPYeBMlvfnUcRkpE-ahhWlVo', 2.369999999999999)
# ('ChIJpXFwOM6WyzsRDNt4k3XaefI', 2.36)
# ('ChIJJxx6Yvl1nkcR3wKvmRIZuW8', 2.36)
# ('ChIJZRsKt-p3nkcRC4npIl4H8wo', 2.36)
# ('ChIJKf2foPQHdkcRjiKwffj6LfQ', 2.3449999999999998)
# ('ChIJy8u1ail0nkcRrs9UcP8PYTI', 2.34)
# ('ChIJn2eIyrh1nkcRJvpjJ8tXFjA', 2.3225)
# ('ChIJp8VtcDyXyzsRvrUJd6PPex0', 2.315)
# ('ChIJkxeZpf5RqEcR5TkFkROUSjY', 2.3099999999999996)
# ('ChIJf6JbhL91nkcR1TtV570LWV8', 2.3099999999999996)
# ('ChIJScWaaop1nkcRSalI_h--24Q', 2.3)
# ('ChIJEe9h-r91nkcReDKcmuY8d50', 2.298333333333333)
# ('ChIJz45Ky1jfnUcRk6tNEyggPHk', 2.285)
# ('ChIJ636rWFjfnUcRQnYqEhCOCOY', 2.285)
# ('ChIJI9krDPd1nkcR1lSv1ZktM2Q', 2.2800000000000002)
# ('ChIJbZvz-OGum0cRdQIMkI66ho8', 2.2799999999999994)
# ('ChIJnZon_exynkcRZLGBheWV3fY', 2.275)
# ('ChIJvQjlg1jfnUcRaqJeLcXVaOY', 2.265)
# ('ChIJlbZj3Ox1nkcRW8Y8oyI5ctM', 2.2574999999999994)
# ('ChIJU1VVIuh2AjoR0W7F_rNzRlg', 2.25)
# ('ChIJEfzCO7r9mzkRHFoXu7K_eCw', 2.25)
# ('ChIJ7SBCFut1nkcRd21KyPLeybw', 2.25)
# ('ChIJs_zqzsZ1nkcR64tMGlIIJ0Y', 2.2349999999999994)
# ('ChIJ8ZPLqfV1nkcRcOow7jfQLYk', 2.23)
# ('ChIJR57nRIp1nkcRDLPGy5wHmXI', 2.2249999999999996)
# ('ChIJ9zVssl7fnUcRP5x91pNJH-Q', 2.2099999999999995)
# ('ChIJicOwNVzfnUcRznn5i-zriFY', 2.2049999999999996)
# ('ChIJwUCcQbh1nkcRpT0HcxtOHmU', 2.184166666666666)
# ('ChIJ7QZjgV_fnUcRQYr2Ii8RwOY', 2.1697899848525353)
# ('ChIJvwexSLAHeUcR3BmoltM0YJI', 2.165)
# ('ChIJ6QYr2XMmnkcRKr5zSdtqDqw', 2.16)
# ('ChIJOfO-9ul1nkcR63_Pf96lg0I', 2.1599999999999993)
# ('ChIJOUO1yXIznkcRNxdmnzYWAQU', 2.15)
# ('ChIJi9exExC2yhQRE6xAOUOUZ8M', 2.15)
# ('ChIJIeM-rOt1nkcRKGqmYyc5fPY', 2.145)
# ('ChIJdSBLuvd1nkcR6iLDrfodk5Y', 2.14)
# ('ChIJC27CAfR1nkcRiK0NpJ9vrQ4', 2.1374999999999997)
# ('ChIJSQbzt_Z1nkcRcM7Sk9e4hwE', 2.1349999999999993)
# ('ChIJtzxWJeF1nkcRrizhO5GmNc0', 2.116)
# ('ChIJy2Yzbyl0nkcRiUFD1IXRkSo', 2.1149999999999998)
# ('ChIJYzzYuXPfnUcRjs1rhwS82JI', 2.1149999999999998)
# ('ChIJyXn4u4t1nkcRF6utwBttGKQ', 2.1099999999999994)
# ('ChIJhc9lA7l1nkcRHO4RRDPSM1g', 2.1099999999999994)
# ('ChIJ_20mWmnfnUcRz4gOZ0yNojc', 2.1)
# ('ChIJHf4YMgKRnkcRqU_6mj8Jnjo', 2.1)
# ('ChIJtbKZ_rd1nkcRNc9L1q89c7Q', 2.0949999999999998)
# ('ChIJ-ymJ1k3fnUcRqn9IGvIjWss', 2.084999999999999)
# ('ChIJhxqfakzfnUcRYYQHZ-AfPzM', 2.0833333333333335)
# ('ChIJ5yB36WbfnUcR6Q8TEb5Pw1M', 2.08)
# ('ChIJF-hso-t1nkcR-U0xgkt__3M', 2.0749999999999997)
# ('ChIJeZ3ZCxZ2nkcRC_F0BX9FDtM', 2.07)
# ('ChIJ9YMYbEFznkcRw2lPUfKkLoE', 2.07)
# ('ChIJ8eTZSFffnUcRCKrmDW2cJi8', 2.07)
# ('ChIJZTxaobl1nkcR1IUTgyD9EWM', 2.0599999999999996)
# ('ChIJ5RU_54l1nkcRGcgbZINlpMk', 2.0577272727272726)
# ('ChIJ-5vFZuZ1nkcR0Z6GAcbVX08', 2.045)
# ('ChIJn-V2U6_YnUcRZAUheUbVza0', 2.04)
# ('ChIJOeXL20F2nkcRLcPjHEDJjrg', 2.0383333333333336)
# ('ChIJRU47VRcKeUcRdgQDoz930Ss', 2.035)
# ('ChIJVxy2Oft1nkcR28oAj6_JAWw', 2.0249999999999995)
# ('ChIJz3tpnA3OnUcRPSeD8kyRu4A', 2.02)
# ('ChIJc0zLmkzIlkcR8eahpX6vnqY', 2.02)
# ('ChIJJWxmUil0nkcRUsQKYP8wZQY', 2.015)
# ('ChIJSaTJyuV1nkcRITRsTXaiARA', 1.9999999999999996)
# ('ChIJO0W6n11iDWsR8ed53VY6CTU', 1.9999999999999996)
# ('ChIJf1vDyfR1nkcR6xnseNKTYGU', 1.9899999999999998)
# ('ChIJz5Y6At3kmUcR2tnooD8-CDs', 1.9849999999999999)
# ('ChIJoY0AXl3fnUcRqN5tWc7XJg8', 1.9849999999999999)
# ('ChIJ8fPPTu7YnUcR6yMAX44mXOM', 1.9849999999999999)
# ('ChIJe8ga9v11nkcRX8CtPNbgTJs', 1.9814285714285718)
# ('ChIJM_MuzZY1mUcRqnlDHGfFFb4', 1.9725)
# ('ChIJ60Sm--V1nkcRv_e5yinXKME', 1.9716666666666667)
# ('ChIJkcC2Bl7fnUcRqxD5-VSvwMM', 1.9699999999999998)
# ('ChIJd7TOM2_fnUcRUXLWos6-O_M', 1.9699999999999998)
# ('ChIJnVCFCPl1nkcR2-0HTPR2B7U', 1.9666666666666668)
# ('ChIJaw4xxkrfnUcRrtP5DRrC_Fk', 1.965)
# ('ChIJBTcMWz39YkcRvC-dx4gnHLk', 1.965)
# ('ChIJ1bcgsW_fnUcRsq9kNhPbLWI', 1.965)
# ('ChIJR81oIb91nkcRGUbJIaSU8J8', 1.9649999999999996)
# ('ChIJ8edul6AHbUcR6faY3loHwaI', 1.9620759155306067)
# ('ChIJRebFi_V1nkcRkiYIjwCQ33A', 1.96)
# ('ChIJKS0MY-Z1nkcRFJd34UfOetA', 1.96)
# ('ChIJyyutSvV1nkcRvfYMURk_ryQ', 1.955)
# ('ChIJA2WozONv5kcRDN_4jmUSXBk', 1.9499999999999997)
# ('ChIJ-9GniGLfnUcRwLXKGbZzdik', 1.9449999999999998)
# ('ChIJDcGVMC52nkcRYSGaHm491IQ', 1.9425)
# ('ChIJhyi-iL91nkcRLT6yt9cgRf0', 1.9406249999999996)
# ('ChIJzdL1tep3nkcRIGggl3NMjhA', 1.94)
# ('ChIJnxlJ14p1nkcRyRBV1aVnSjY', 1.9249999999999998)
# ('ChIJXwPCMQ92nkcRhV59F2-BmOE', 1.9216666666666664)
# ('ChIJ9wbqT9tBOxMR11YAMD-tCMw', 1.9199999999999997)
# ('ChIJkxhfBm50nkcR2cAUnFgl_lc', 1.9199999999999997)
# ('ChIJiw01Qop1nkcRvZRx8z-Unbo', 1.9175)
# ('ChIJx19N3LUynEcRPhsYgQZ5tvU', 1.905)
# ('ChIJd784Nj10nkcRGEkU95oNBxk', 1.9049999999999994)
# ('ChIJnSuRhevgnUcRV9GUC5Ayy6I', 1.9)
# ('ChIJO33lbex1nkcReqENVvSPak8', 1.899)
# ('ChIJjU2sObJ2nkcRY3KOr-SpdKA', 1.8949999999999996)
# ('ChIJ76_VOet3nkcRVoIOLhy63MY', 1.8824999999999998)
# ('ChIJlVy_kut1nkcRMjKRjpBC6T4', 1.8800000000000001)
# ('ChIJS_gMjoHfnUcR9n73bsj3kBI', 1.875)
# ('ChIJf4AoOmDfnUcR3GjmXg2UPuI', 1.875)
# ('ChIJUWFHDb91nkcRs5VWZB5ZGd4', 1.8699999999999997)
# ('ChIJSQbzt_Z1nkcR-FyOQcmfG9s', 1.8668750000000003)
# ('ChIJm5KyvAQLdkcRfUr-D_9PjiU', 1.8650000000000002)
# ('ChIJLZdndoV1nkcRgnJs-3YNPJw', 1.8599999999999997)
# ('ChIJawdkfQX4CEERDdnRQLZC420', 1.8575)
# ('ChIJQZp1oPt0nkcRiqFr_RTKItw', 1.855)
# ('ChIJhZN8eLh1nkcRfM0JftIyGX0', 1.8524999999999998)
# ('ChIJ21O6RMPYnUcRbDV-_4BpW-k', 1.85)
# ('ChIJrWWbTlrfnUcREzlWn8i5Ko8', 1.845)
# ('ChIJ-6LRkex1nkcRpfolAl0dCBQ', 1.835)
# ('ChIJT-EVUzXfnUcROaisVzQrV8k', 1.8349999999999995)
# ('ChIJl5gkzeV1nkcRP_m-l4_qYxA', 1.83125)
# ('ChIJDbsXX2DfnUcR1faseFaTzPI', 1.8299999999999996)
# ('ChIJV8rJWPR1nkcRfAVGOrZIeVs', 1.8299999999999996)
# ('ChIJwVrzjv9ynkcR45x408cJotc', 1.8249999999999997)
# ('ChIJo-2ZufR1nkcRWEZYKjOWbio', 1.8249999999999997)
# ('ChIJ27XDA2-xdUcRh-PcbNwcvNA', 1.8249999999999997)
# ('ChIJ6a3yJ4qGcUERrpHWrxq_k8I', 1.8150000000000002)
# ('ChIJnUSq6_J1nkcRRXo0Cz9qHEY', 1.815)
# ('ChIJebYCmL91nkcRxywDKjTIlzo', 1.8119999999999998)
# ('ChIJpSww8ULfnUcRdXasT5xHJ44', 1.81)
# ('ChIJuz1If2LfnUcRLPZYvM-t0Cc', 1.8075)
# ('ChIJRf_Iy-V1nkcRYkahFTv_cv8', 1.8049999999999997)
# ('ChIJDaqRkya_woARN85cYzM3cbA', 1.8049999999999997)
# ('ChIJ2_43wc5S8DURiAu9njSliGE', 1.8033333333333328)
# ('ChIJ13uMbEfUnUcRDVU5YxZccoE', 1.7999999999999998)
# ('ChIJxfxSz4t1nkcRLxq9ze1wwak', 1.7945454545454544)
# ('ChIJX6cuPgvBn0cRHJMxNDvV0JI', 1.79)
# ('ChIJGymGb13fnUcR42wkD59XZLw', 1.79)
# ('ChIJBer6x5XPnUcRbrhTfvH624E', 1.79)
# ('ChIJV68FLXfinUcRIhnw61VZSUE', 1.79)
# ('ChIJh6YG555_LRMR8NTp8XuO_8M', 1.79)
# ('ChIJtwMlbmnfnUcRPhgrK5ENZ8s', 1.79)
# ('ChIJL3wPArAHeUcRFxPIb8gC4nQ', 1.7899999999999994)
# ('ChIJYfCeKkx0nkcR2yFR6xpGC0Q', 1.788333333333333)
# ('ChIJeT1NDup1nkcRrvWxdwfMpSY', 1.775)
# ('ChIJrRdqUO91nkcROzFfYdW0mjM', 1.775)
# ('ChIJI9FJdMB1nkcRC32DTqPXMFw', 1.7700000000000002)
# ('ChIJGQwFl1DfnUcRQ_R4caDq1f0', 1.7699999999999996)
# ('ChIJdceZ6VjfnUcR0lz1CRSg8OY', 1.7674999999999998)
# ('ChIJPanmHx4vyTURBlnPmhnQ6mI', 1.7650000000000001)
# ('ChIJ7cW6qbl1nkcRZ9-9tkTNUPw', 1.76)
# ('ChIJC54i61DfnUcRqRL3ZnzHJ3E', 1.76)
# ('ChIJZck49IV1nkcRIfjq1j1JlUo', 1.7574999999999998)
# ('ChIJhejyFgolv0cRx4ujJqXHSFc', 1.7541666666666664)
# ('ChIJL8da3wKAMhMRhEiMKzeggEY', 1.75)
# ('ChIJp3iZ5Fp0nkcRtmKdWM2zQPI', 1.75)
# ('ChIJv6cFqOB1nkcRtDDB8nQKndU', 1.75)
# ('ChIJ-c5XJ4p1nkcRtDee9eN7uAM', 1.75)
# ('ChIJlwo2uYt1nkcRgwFo0PhZze0', 1.7499999999999996)
# ('ChIJG7onr6V1nkcRwj0tZvIapSE', 1.745)
# ('ChIJe5XNX7PYnUcRJQxR4PFPDac', 1.745)
# ('ChIJf6wzBqjYnUcR4FTiNFpZ5lo', 1.7399999999999998)
# ('ChIJz-OGvFvfnUcRiYJWHpxESew', 1.735)
# ('ChIJP5Ilxr4HeUcR2EINyjdjeQA', 1.735)
# ('ChIJKbF-66GStTURocdSH5CUdnI', 1.735)
# ('ChIJXdJlyDjUnUcR2vUfgFrkmlI', 1.73)
# ('ChIJBegRr0flnUcR_zxTveqGI4s', 1.725)
# ('ChIJdeXDgFrfnUcRwYPI0V7JfY4', 1.725)
# ('ChIJFc8Tpvt1nkcRksgh1aspaSk', 1.725)
# ('ChIJbTJCb2J1nkcRhMX1rN7JwFM', 1.7249999999999996)
# ('ChIJ0aVSGy0L1kgRJ7bAsSZ2Ac8', 1.7249999999999996)
# ('ChIJEZNnxZ_fnUcRJUrLRSM02mA', 1.7249999999999996)
# ('ChIJD6Zlu7l1nkcRHzQXumBnFjU', 1.7239999999999998)
# ('ChIJb4RsWL4HeUcRt3xmoJUkVOU', 1.7199999999999998)
# ('ChIJN7wi_2DfnUcRk5JVafGkGRU', 1.71)
# ('ChIJG5xhq_9ynkcRJaNeYUx_dv0', 1.7066666666666666)
# ('ChIJ8dHXli3lmUcRbSsbGrUNotc', 1.705)
# ('ChIJHeg9F1_fnUcRodyOlcSDA7Y', 1.7048923044937478)
# ('ChIJc-huVdT6mUcR81h3AxKXJVw', 1.7)
# ('ChIJVQoueo7YnUcRnG_DJZSt4vM', 1.7)
# ('ChIJj9spBWDfnUcRqBwfNs-ZEL8', 1.6999999999999997)
# ('ChIJ5RNJ2vh5nkcRh_h3gh7kKk4', 1.6949999999999998)
# ('ChIJPTp25_Z1nkcRv-WOSere1aI', 1.685)
# ('ChIJ5xo8_OxynkcR3Fn9nBDptMQ', 1.6824999999999999)
# ('ChIJ7x74GfCifDURbInzekuklzA', 1.6800000000000002)
# ('ChIJsTbLhx7-CEERYm8tsJLgXlE', 1.6799999999999997)
# ('ChIJ2_xHZ3RFyTURObKm-zOC4tg', 1.675)
# ('ChIJvybdFjxrnkcRfP1mLxETNdg', 1.67)
# ('ChIJnTdkWvt1nkcRorkL8OCZRoo', 1.6599999999999997)
# ('ChIJY3FhsO51nkcR-_uvwjXmh_w', 1.6599999999999997)
# ('ChIJ_ZkgKcF1nkcR2w7B_bbjutI', 1.6599999999999997)
# ('ChIJo6uwlWLfnUcRw4KsGTPTJXE', 1.6550000000000002)
# ('ChIJtQQHpJR1nkcR1rIHF0cT-M0', 1.6549999999999998)
# ('ChIJpcSownBOyTURmP0VXIsQ6QY', 1.6524999999999999)
# ('ChIJ5yW5g-_YnUcRVTTBNb7xfho', 1.6499999999999995)
# ('ChIJ1_roxSt0nkcRjd1cTPqr0BQ', 1.645)
# ('ChIJlwwDkOxv5kcRbaSJSKYoEgs', 1.645)
# ('ChIJGWAg7zdznkcRVPNxQCF7d-o', 1.6417894571097016)
# ('ChIJEVc9jA6cnkcRF4jcSTNoGZQ', 1.6349999999999998)
# ('ChIJUZi2IhCcnkcRGAO-bRMY_H4', 1.6349999999999998)
# ('ChIJ_SjJmeZ1nkcRlik_AcAdA8E', 1.6349999999999998)
# ('ChIJ1UWPmtt1nkcRICYi7vP2BQ4', 1.63)
# ('ChIJuUl8k2pmUjoRoc2Uc-SrH_M', 1.63)
# ('ChIJpVUc6gh2nkcR1tmy6eibHis', 1.62)
# ('ChIJr-zz_OxynkcRF4Oyo_JCEDw', 1.62)
# ('ChIJYe0scEicnkcRarj0hJNGbP4', 1.62)
# ('ChIJc18o97h1nkcR2v7btxWODX0', 1.6100000000000003)
# ('ChIJDzXHbrx_LRMRBg12WxxGvmw', 1.6099999999999999)
# ('ChIJN1ZekWLfnUcR1QJuAZdyQKQ', 1.6099999999999999)
# ('ChIJeRrgJR1nUjoRjWJqtY7F-QQ', 1.605)
# ('ChIJrf0XyGbfnUcR_z0dCtYXR8c', 1.605)
# ('ChIJBbPSPNQFdkcRqkhHgg-7bvo', 1.605)
# ('ChIJU2i7zAB2nkcRBZ3nbBsKO10', 1.5999999999999996)
# ('ChIJ-4sMvokZY0cRw6sOWmw3h8A', 1.5975)
# ('ChIJQQ8lDPl1nkcRIlFIDny9LxY', 1.5949999999999998)
# ('ChIJ1x8d05sIOxMR4YY_cIYx6Mk', 1.5899999999999999)
# ('ChIJGXWiYCp2nkcRSs0fgoHJ858', 1.5899999999999999)
# ('ChIJs58_snYGeUcR3S614EelM3s', 1.5899999999999999)
# ('ChIJoQgQVW7fnUcRJ0wlXSI2SaQ', 1.5899999999999999)
# ('ChIJg8uT8yjfnUcRQUaLoEQdiz0', 1.5899999999999999)
# ('ChIJ1cl5OQl2nkcR5VBF8X-772Y', 1.585)
# ('ChIJ7yG9ZcF_LRMRzLNkZJSl5Sg', 1.585)
# ('ChIJk12CGdj1r0cRimIFPTIyueQ', 1.585)
# ('ChIJb8qbNKrYnUcRmTIK1niVTRM', 1.585)
# ('ChIJ85WkHE48nkcRB3urSc0VYow', 1.585)
# ('ChIJicU4Kj52nkcROo7KLgbsWYc', 1.58)
# ('ChIJZ3osp46MtTURJkNq_vgSJpQ', 1.58)
# ('ChIJnZ9UnLl1nkcRWJex_7H-20o', 1.5799999999999998)
# ('ChIJmx2juHVrnEcR-F7zS8QV_rc', 1.5750000000000002)
# ('ChIJJ7Dh0qjYnUcRzTcmSrusvoQ', 1.5749999999999997)
# ('ChIJFwSNT_IBCUERKgoTuCz6Lho', 1.5716666666666665)
# ('ChIJr7WWf7kHeUcRQZuLhbivtu8', 1.5699999999999998)
# ('ChIJvz3Ntrlx5kcRCylrI3QARlw', 1.5699999999999998)
# ('ChIJDZRuZ4t1nkcR8kMVtpyBMt0', 1.5649999999999995)
# ('ChIJM8L39yXEnUcRk8aJInSyZdg', 1.5649999999999995)
# ('ChIJL2tI6dzgnUcRUjYFu6Zg7OY', 1.5649999999999995)
# ('ChIJAfSN-AZjnkcRQafzW5zoDHk', 1.5624999999999998)
# ('ChIJr7TvV-R1nkcRC5kjABpoGLA', 1.5599999999999998)
# ('ChIJUb-uEfrfTEYR8u86Y5Jhzq8', 1.5599999999999998)
# ('ChIJL95pBLt_LRMRbUth8uqQAm4', 1.5599999999999998)
# ('ChIJUcJs8OcLnkcRse1PCHZJ1_E', 1.5599999999999998)
# ('ChIJj5XQHMlC1moRr-au_PgprUY', 1.5599999999999998)
# ('ChIJi5CqAlrYnUcRTII0xmeFTNM', 1.5550000000000002)
# ('ChIJ59GsrOR1nkcRMg90PlBcWZQ', 1.5550000000000002)
# ('ChIJ0UD5ynImnkcRQxXSiNtjAw0', 1.555)
# ('ChIJY-FRmV6ALRMRc-3yZ8261ko', 1.555)
# ('ChIJMa1hXIp1nkcRlbN72jsWSCQ', 1.5516666666666663)
# ('ChIJUxIn3WbfnUcRtZEI7zJxi8s', 1.5500000000000003)
# ('ChIJ1-CWzM5S8DURznhiUAHBvn0', 1.5500000000000003)
# ('ChIJ2YJ3mHzfnUcRZ8LfM7KI30k', 1.5499999999999998)
# ('ChIJQ7Pxy-R1nkcRolT7hLAr5Ak', 1.5449999999999997)
# ('ChIJDVLEaot1nkcRIcYDAStkpc4', 1.5449999999999997)
# ('ChIJTxt4h1DYnUcRT5zsqo15oa4', 1.54)
# ('ChIJiZ1PW1DfnUcRxRuM8f59N_Q', 1.5374999999999996)
# ('ChIJU_anGPp3X0YRTIbCK2z6-bA', 1.5349999999999997)
# ('ChIJw3DFUYLfnUcRfvBCAC1K0Bc', 1.5349999999999997)
# ('ChIJ-22Pf_B1nkcRVGrTPtHl_HU', 1.53)
# ('ChIJy7Fh4-V1nkcR1_htBHgiz5U', 1.5299999999999994)
# ('ChIJHYnxu_d1nkcRxcqt1g3epfA', 1.525)
# ('ChIJb1FvNTJznkcRh2m6-QD0Sxk', 1.525)
# ('ChIJT5FE2_d1nkcRWgx9bskMvoE', 1.52)
# ('ChIJhRqTJop1nkcRtORqruqmdQk', 1.5150000000000001)
# ('ChIJ8RTFfg3IkUcRrt8kx9e1GAk', 1.5150000000000001)
# ('ChIJJUm5el10nkcRWpdZtfNCRfE', 1.5150000000000001)
# ('ChIJYRIBPAh2nkcRrmROwkVcR2E', 1.5124999999999997)
# ('ChIJ07CxgJl1nkcRA1A5FBRRz-8', 1.5100000000000002)
# ('ChIJWY1mvo2MtTURbY3p7RgWiAI', 1.5099999999999998)
# ('ChIJg30bkSRfCEERhhzNxeoK5KU', 1.505)
# ('ChIJN7kaXf5ynkcRpGXGwj8KDhY', 1.5012499999999998)
# ('ChIJbfz9jbAHeUcRqksxL09xMa0', 1.5)
# ('ChIJ-bkTNdl1nkcR9QXkretobMQ', 1.5)
# ('ChIJ1eBtPGZtiEcRmukTMhWOemU', 1.5)
# ('ChIJC25Ks-hx5kcRmxTAIkl62vg', 1.4949999999999999)
# ('ChIJ3wpBDB97n0cRmo8HFpHmL_U', 1.4899999999999998)
# ('ChIJ99EvYCh0nkcRDUDbGZm84gw', 1.4875)
# ('ChIJj_5_TA-cnkcR1TqzNLsoPno', 1.4849999999999999)
# ('ChIJXdMIS_N1nkcR_gpA4OGgDTc', 1.4849999999999999)
# ('ChIJ9Q7E2zB0nkcRaMhUZSHtjvM', 1.48)
# ('ChIJEUO_cUcJdkcR19pG0xTVNzc', 1.4749999999999996)
# ('ChIJ479Qk7JS8DUROBfMaOFMUQg', 1.47)
# ('ChIJO6MKlPB1nkcRziC9tAYY7WI', 1.4649999999999999)
# ('ChIJM-tMH8p1nkcRh0ybNfwMp2I', 1.4649999999999999)
# ('ChIJ46BKj1rYnUcRI9qaSnuBISk', 1.4599999999999997)
# ('ChIJx5-MpX3fnUcR9Tsy83A7Q2c', 1.455)
# ('ChIJC0FJUdPYnUcRuTp6EPpQQ70', 1.455)
# ('ChIJr7Rijr5_LRMRR1lUlUP-Ee4', 1.45)
# ('ChIJIT-4CnWxdUcRqrb5UcasMbU', 1.4491882626973114)
# ('ChIJo1taZYwBCUERoLKitMOdtdw', 1.44)
# ('ChIJQW0wSr91nkcRZbyUT_e-uas', 1.4399999999999997)
# ('ChIJE8Fr_kPfnUcRvw4X8mPGuYc', 1.435)
# ('ChIJh_WMwSv_CEERVxbuWsVnSeI', 1.435)
# ('ChIJiWEtVJHfnUcRXEJVWxvcL0c', 1.4299999999999997)
# ('ChIJYWUkRh_gnUcR3VU29ofuXVw', 1.4298626926846654)
# ('ChIJcwwwBtP6mUcRzrLJR8kF6MQ', 1.425)
# ('ChIJycU7ED9QyTURqjwt0QnmYas', 1.425)
# ('ChIJwWiCvOt1nkcRI56cKONAkwg', 1.4200000000000002)
# ('ChIJV-V2xoV1nkcRju3rr5kFfLE', 1.42)
# ('ChIJEWeIqPJynkcRYVXXXfj2Fps', 1.42)
# ('ChIJa5ereg11nkcRA56iv0O5peE', 1.415)
# ('ChIJl9ieS-QlnkcRa5phBM-c0Aw', 1.415)
# ('ChIJ1ZjrSYp1nkcRmsU5W9ezu8U', 1.415)
# ('ChIJm2QRcsZ1nkcRJClgP1qTovs', 1.415)
# ('ChIJzb1N8OxynkcR_ufg6x5BLCg', 1.41)
# ('ChIJMxRR4fZ1nkcRRuh1AGGTenk', 1.4085714285714284)
# ('ChIJnXCJ7_J1nkcR6vRc2lazYME', 1.3999999999999997)
# ('ChIJNy_A8u4CnUcRnD13U6UFaRA', 1.395)
# ('ChIJbUfBymDfnUcRfJHAjijfHSA', 1.395)
# ('ChIJlwc8cBVTmUcRfBM-K6vyXY4', 1.3925)
# ('ChIJjzcOtRcmnkcRxAy5u1opM7Q', 1.3900000000000001)
# ('ChIJVa3Hi4V1nkcRhYmLt1QWF4c', 1.39)
# ('ChIJvzNjhensDzkRQ5lxfBuYzyY', 1.39)
# ('ChIJy1-eyb8HeUcR7L-Xkuz5I2o', 1.39)
# ('ChIJXauUCXjfnUcRSzwNxiPdfIw', 1.38)
# ('ChIJNd8IM990nkcRocp8kTcELtQ', 1.38)
# ('ChIJK2YLxekQgkcRJj1vDKb7HHA', 1.3749999999999998)
# ('ChIJeXr7aIsHdkcRTLGS-1IxGlY', 1.373333333333333)
# ('ChIJlxbvxl7fnUcR2sQR9gv-h_c', 1.365)
# ('ChIJUeeIpWDfnUcRsf5OpxWbjxY', 1.355)
# ('ChIJHwJNaX53nkcRGSYuixLDJXE', 1.35)
# ('ChIJQeFv7bh1nkcRwIU0PdIJIEs', 1.3449999999999998)
# ('ChIJn82-Depv5kcRbitLK3lP0Bg', 1.3449999999999998)
# ('ChIJh_zeT46MtTUR5jdQl1UUJIg', 1.3449999999999998)
# ('ChIJf9f0PKhYdEcR4Nz-_Y_fnpo', 1.335)
# ('ChIJHSyJS_5ynkcR1hC2vf5bVCs', 1.335)
# ('ChIJl858IcJ1nkcReZeWKjn6ysc', 1.3249999999999997)
# ('ChIJxWSAXkd1nkcR87PUTzkpVuU', 1.3199999999999998)
# ('ChIJVVWxZ-R1nkcRrYkjIyFsKew', 1.3199999999999998)
# ('ChIJe28YeoHfnUcRSiQFL5pfT1c', 1.31)
# ('ChIJr15c7QH2dEcRP_0_dHfizN4', 1.31)
# ('ChIJVVVVValYdEcRLfUSsFYEsRk', 1.31)
# ('ChIJk6myycN1nkcRKMsoxJKcEps', 1.305)
# ('ChIJ6cmn1AfZnUcR9oe5ICHxLTU', 1.305)
# ('ChIJ95BJt8rYnUcRB0Ga4sJFNxw', 1.29)
# ('ChIJ4ZUSFeyUC0cRV7WrymAISVw', 1.2899999999999998)
# ('ChIJ0ZW-jUcmQg0RlNxO4kEq7Go', 1.2899999999999998)
# ('ChIJRVdhXI9_LRMRkN3XPa1Baj0', 1.285)
# ('ChIJiS5pIOx1nkcR4Eo2VJD4TTk', 1.285)
# ('ChIJ7a2TAMD3cg0RD8K-iOjCzIo', 1.2799999999999998)
# ('ChIJk9IxjKt7nkcRZtsmTuXoTuU', 1.2799999999999998)
# ('ChIJfXabyop1nkcRBgyYVSK47qU', 1.2799999999999998)
# ('ChIJsal6wvR1nkcRCHvfcJC60iE', 1.2799999999999998)
# ('ChIJab0H05-xdUcR-JzdcY5tXnQ', 1.2676069796427087)
# ('ChIJN_bkN-13nkcRhEdTUVxp2Ec', 1.2650000000000001)
# ('ChIJt8qQpO8DCUER0nYToh_dZbA', 1.2650000000000001)
# ('ChIJpZqF1kFFyTURxkNXcY74jGU', 1.2650000000000001)
# ('ChIJcbRVpkVNdEcRV1YJYx06lFY', 1.263333333333333)
# ('ChIJ7YIP_ex1nkcRmHP7GDsDxM4', 1.26)
# ('ChIJH1TQ28CkLBMRbj7dbApISNo', 1.2599999999999998)
# ('ChIJQxG40VdlsjURSVhPepPO3Vo', 1.2599999999999998)
# ('ChIJ32MZl_N1nkcRAoAJV40ou20', 1.2550000000000001)
# ('ChIJi6KRyCp3AjoRSWrvZ6arG9Q', 1.25)
# ('ChIJvWJZAX11nkcRnT-Q6Pb-rkw', 1.25)
# ('ChIJq6qq2t12AjoRvyqwtgaREPE', 1.25)
# ('ChIJoSrsRP5ynkcRjqG5rBuYZTU', 1.25)
# ('ChIJSZ3-rLl1nkcR6VOGLgdlPL0', 1.25)
# ('ChIJvS68Ob91nkcROz72PRxVZzI', 1.25)
# ('ChIJqwG7v_d1nkcRmBuYTdGkJcA', 1.25)
# ('ChIJP5GJtdKxEmsRqwQxZALwse0', 1.25)
# ('ChIJ1_jEhV4omUcRg082AzZ-4yA', 1.2499999999999996)
# ('ChIJd6MPE5V_LRMR9Hy8jwH_m8E', 1.2449999999999999)
# ('ChIJd05W5wD2dEcRHyt3CGpILlQ', 1.24)
# ('ChIJq9Dm5Yp4LRMROzQQHTbnHXc', 1.24)
# ('ChIJI8AhzSzOnUcRGPpB7EhLhNw', 1.2349999999999999)
# ('ChIJF8qBYm9rnEcReA0H-xSHU2o', 1.23)
# ('ChIJ4wviTeR1nkcRZz0pYWKDVpY', 1.2199999999999998)
# ('ChIJO6LZKIh1nkcRiYpaRyUkxLw', 1.2149999999999999)
# ('ChIJOQn5CPl1nkcRFsylk6h8X1Q', 1.2149999999999999)
# ('ChIJQT66icd1nkcRsTUHokN2-Sk', 1.2099999999999997)
# ('ChIJq733sqoOvUcRgGlyBisjbLo', 1.205)
# ('ChIJEZGL2wh2nkcRZwAmh2VRphc', 1.2049999999999996)
# ('ChIJnedKEVrYnUcRlTOB7137l6Y', 1.2049999999999996)
# ('ChIJWSpmWop1nkcRZSRCDS-wOeU', 1.1999999999999997)
# ('ChIJ1y7jYk48nkcRvEq2q8W0R8Y', 1.1999999999999997)
# ('ChIJkXU5GJAPCUERmS_E6L-EYE0', 1.1961111111111113)
# ('ChIJs1dbvWXfnUcRA_sNidoOQZw', 1.19)
# ('ChIJHZnsh4rFCUcR_pYjytqEc-k', 1.1899999999999997)
# ('ChIJOSMm19P4CEERiSPEKchhT24', 1.18)
# ('ChIJbfe_W4ffnUcRLvUQJ-XgyJ8', 1.1722859306780717)
# ('ChIJsWTRF1bfnUcRMfqEdeR-KOs', 1.17)
# ('ChIJxymsyg6cnkcRSyUIXSU8hx8', 1.17)
# ('ChIJTQlycvl1nkcRfNr4k7SUkxg', 1.1675)
# ('ChIJJ6elAkKU3UYRmU-_Tk-SFTI', 1.165)
# ('ChIJkeQBdEIQnkcRDN847YEFdcM', 1.1600000000000001)
# ('ChIJocgBxvMHeUcR9VdSjJw7Bfs', 1.15)
# ('ChIJU-1sZfd1nkcRJqNANAsmEEA', 1.15)
# ('ChIJTWgnK3tFyTURDZB38VaOnsA', 1.15)
# ('ChIJV4cMh6fZnUcRT3u7R3FISjo', 1.1399999999999997)
# ('ChIJvZIzNvYlnkcRvi_1t7J_1Rk', 1.125)
# ('ChIJryc5X9p1nkcRRWQ0nk1JE3I', 1.115)
# ('ChIJ-6NCOokBCUERl-2iFjRC5VA', 1.1)
# ('ChIJ4fardXXIkUcRmbenGNHoM9c', 1.095)
# ('ChIJW39zDbfYnUcRyLvLyLSUJqU', 1.08)
# ('ChIJiQaMr_d1nkcRhZgP1_GEwAQ', 1.065)
# ('ChIJaxZXJA1FyTURznAn61IA8Rg', 1.065)
# ('ChIJidSoDBzgnUcRny_WAQ7PaCI', 1.061825536843981)
# ('ChIJgaB8m0t6nkcRETbo0mtSqP4', 1.0599999999999998)
# ('ChIJbcNioPt1nkcRrLtE6XS-Oec', 1.05)
# ('ChIJfemt4Ll1nkcR9C6vY3NGfM8', 1.045)
# ('ChIJ7cha3E9NdEcRm3ZJ_tKCNZ0', 1.03584590817014)
# ('ChIJ17bklcGkLBMRC_vnSUtCxV8', 1.025)
# ('ChIJXbtEszGufkcRIcu_iuFC9VM', 1.0150000000000001)
# ('ChIJzy-RbJp1nkcRKpmkA1CKLwo', 0.9999999999999998)
# ('ChIJJ3r1Iux1nkcR89Q02AjDWJ0', 0.995)
# ('ChIJdXJ_ZXffnUcR7lQpdb6iX5Q', 0.995)
# ('ChIJf8-tUy_fnUcRmtMuAQeXRE8', 0.9903069589236388)
# ('ChIJWWkdEu91nkcR2N_X9ikHlws', 0.9699999999999998)
# ('ChIJA1DHoinQnUcRtoOkl6wWUBo', 0.965)
# ('ChIJ2bbivOR1nkcR4BMbEXLaefU', 0.965)
# ('ChIJH8uh6tvgnUcRVuIAlycoaUk', 0.9449999999999998)
# ('ChIJzxAuRH4GdkcRoUzfbYzVuQc', 0.9225)
# ('ChIJB9Wc0p51nkcR4f8MhYf66Oc', 0.88)
# ('ChIJvR7MZWNrnEcRBZDfNzTf7ws', 0.875)
# ('ChIJeQSK5Nx2GRMRulQZMlI5Qcw', 0.8699999999999999)
# ('ChIJk5qkn4F1nkcRRCvIqAG2Iw4', 0.8699999999999999)
# ('ChIJVdJ4Ibh1nkcRqRcBFOeeQcY', 0.8450000000000002)
# ('ChIJ4Z7tHXHfnUcR9ipc7_YU1AQ', 0.8450000000000002)
# ('ChIJBXbHDq25kUcRMXnWh1KtbwQ', 0.8399999999999999)
# ('ChIJzdQFn3MmnkcRKoMBrqIyTIs', 0.835)
# ('ChIJvxBELgmcnkcR84FDN7_gOsA', 0.8200000000000001)
# ('ChIJJTb-tfV1nkcRfHfr76wb9uk', 0.81)
# ('ChIJVx0uhVE8nkcRb4t2adszVCs', 0.7949999999999999)
# ('ChIJewAihSUmQg0RFuy-Rzya_mo', 0.77)
# ('ChIJP_4kdr91nkcRkz2Y5FNV0aw', 0.7199999999999999)
# ('ChIJg_2BCLHGhkcRZl_qY7021EI', 0.67)
# ('ChIJSwHJkSZrnkcRqWvnE0PJTd8', 0.42999999999999994)
